# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# # 2. Loading the dataset

# %%
data = pd.read_csv("C:\IBM Nalaiya thiran\Churn_Modelling.csv")

# %% [markdown]
# # 3. Univariate Analysis

# %%
data = pd.read_csv("C:\IBM Nalaiya thiran\Churn_Modelling.csv")

# %%
sns.distplot(data['Tenure'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tenure', ylabel='Density'>

# %%
sns.histplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data['CreditScore'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CreditScore'>

# %% [markdown]
# # 3. Bivariate Analysis

# %%
sns.lineplot(data['Age'], data['Geography'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Geography'>

# %%
sns.barplot(data['Tenure'], data['EstimatedSalary'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tenure', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(data['NumOfProducts'], data['HasCrCard'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NumOfProducts', ylabel='HasCrCard'>

# %%
sns.scatterplot(data['HasCrCard'], data['Geography'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HasCrCard', ylabel='Geography'>

# %% [markdown]
# # 3. Multivariate Analysis

# %%
sns.scatterplot(data['Age'], data['Exited'], hue = data['Age'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Exited'>

# %%
sns.scatterplot(data['Gender'], data['NumOfProducts'], hue = data['Gender'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='NumOfProducts'>

# %%
sns.scatterplot(data['Gender'], data['Age'], hue = data['Gender'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.pairplot(data)

# %% [markdown]
# # 4. Descriptive Statistics

# %% [markdown]
# ## Central Tendency

# %%
data.mean()

# %%
data.median()

# %%
data.mode()

# %%
data.describe()

# %% [markdown]
# ##  Dispersion of Data

# %%
sns.boxplot(data['CreditScore'])

# %% [markdown]
# ### Interquartile Range

# %%
q = data.quantile([0.75, 0.25])

# %%
q

# %%
iqr = q.iloc[0] - q.iloc[1]

# %%
iqr

# %%
u = q.iloc[0] + 1.5*iqr

# %%
u

# %%
l = q.iloc[1] - 1.5*iqr

# %%
l

# %% [markdown]
# ## Variance

# %%
data.var()

# %% [markdown]
# ## Standard Deviation

# %%
data.std()

# %%
data.notnull()

# %% [markdown]
# # 5.Handle the missing values:

# %%
 data.fillna(0)

# %% [markdown]
# ## 6. Outliers and handling them

# %%
sns.boxplot(data['CreditScore'])

# %%
data['Tenure'].mean()

# %%
data['Age'] = np.where(data['Age'] > 50, 39, data['Age'])

# %%
sns.boxplot(data['Age'])

# %%
sns.boxplot(data['Tenure'])

# %%
data['Age'].mean()

# %%
data['CreditScore'] = np.where(data['CreditScore'] < 400, 650, data['CreditScore'])

# %%
sns.boxplot(data['CreditScore'])

# %% [markdown]
# # 7. Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Surname'] = le.fit_transform(data['Surname'])
data['Geography'] = le.fit_transform(data['Geography'])
data['Gender'] = le.fit_transform(data['Gender'])
data.head()

# %% [markdown]
# # 8. Splitting the data

# %%
x = data.iloc[:, 0:4]

# %%
x

# %%
y = data['HasCrCard']

# %%
y

# %% [markdown]
# # 9. Scaling the independant variables

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %%
x_scaled

# %% [markdown]
# # 10. Splitting into training and testing set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.3, random_state = 0)

# %%
x_train.shape

# %%
x_train

# %%
x_test.shape

# %%
x_test

# %%
y_train.shape

# %%
y_train

# %%
y_test.shape

# %%
y_test
